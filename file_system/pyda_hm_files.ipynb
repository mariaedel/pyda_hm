# %%
import json

purchases = {}

with open('purchase_log.txt', encoding = 'utf-8') as f:
    for line in f:
        s = json.loads(line)
        purchases[s['user_id']] = s['category']
        
with open('visit_log.csv', encoding = 'utf-8') as f_visit:
        
    with open('funnel.csv', 'w', encoding = 'utf-8') as new_f:
        for line in f_visit:
            user_and_visit = line.strip().split(',')
            if user_and_visit[0] in purchases.keys():
                new_f.write(user_and_visit[0] + ', ' + user_and_visit[1] + ', ' + purchases[user_and_visit[0]] + '\n')

# %%
proverka = open('funnel.csv', 'r', encoding = 'utf-8')
for i, line in enumerate(proverka):
    print(line)
    if i > 10:
        break
# Out:
# ...

# %%
# !jt -t grade3

# %%
with open('visit_log.csv', encoding = 'utf-8') as f_visit:
    for i, line in enumerate(f_visit):
        spisok = json.loads(line)
        print(line)
        if i > 5:
            break
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-7-6a4fe0e50b18> in <module>
#       1 with open('visit_log.csv', encoding = 'utf-8') as f_visit:
#       2     for i, line in enumerate(f_visit):
# ----> 3         spisok = json.loads(line)
#       4         print(line)
#       5         if i > 5:
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
